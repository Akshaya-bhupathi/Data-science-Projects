# %%
# PROJECT ON FAKE NEWS DETECTION

# %%
pip install numpy pandas sklearn
# Out:
# Requirement already satisfied: numpy in c:\users\srinivas\anaconda3\lib\site-packages (1.20.1)
# Requirement already satisfied: pandas in c:\users\srinivas\anaconda3\lib\site-packages (1.2.4)
# Requirement already satisfied: sklearn in c:\users\srinivas\anaconda3\lib\site-packages (0.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\srinivas\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\srinivas\anaconda3\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\srinivas\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: scikit-learn in c:\users\srinivas\anaconda3\lib\site-packages (from sklearn) (0.24.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\srinivas\anaconda3\lib\site-packages (from scikit-learn->sklearn) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\srinivas\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\srinivas\anaconda3\lib\site-packages (from scikit-learn->sklearn) (1.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import libraries
import pandas as pd
import numpy as np
import itertools
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier

# %%
# Read the data
df = pd.read_csv("news.csv")

# %%
# removing unnamed columns
df = df.iloc[:,0:4]

# %%
# Get the shape of data
df.shape
# Out:
# (7795, 4)

# %%
# This step is to print the information up to 5 columns
df.head()
# Out:
#   Unnamed: 0                                              title  \
# 0       8476                       You Can Smell Hillary’s Fear
# 1      10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2       3608        Kerry to go to Paris in gesture of sympathy
# 3      10142  Bernie supporters on Twitter erupt in anger ag...
# 4        875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
# This step is to print the information of last 5 columns
df.tail()
# Out:
#      Unnamed: 0                                              title  \
# 7790       4490  State Department says it can't find emails fro...
# 7791       8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 7792       8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 7793       4021  In Ethiopia, Obama seeks progress on peace, se...
# 7794       4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 7790  The State Department told the Republican Natio...  REAL
# 7791  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...  FAKE
# 7792   Anti-Trump Protesters Are Tools of the Oligar...  FAKE
# 7793  ADDIS ABABA, Ethiopia —President Obama convene...  REAL
# 7794  Jeb Bush Is Suddenly Attacking Trump. Here's W...  REAL

# %%
# This step is to count the null values
df.isnull().sum()
# Out:
# Unnamed: 0     219
# title          610
# text           866
# label         1040
# dtype: int64

# %%
# Changing into DATAFRAME
df = pd.DataFrame(df)

# %%
# removing the null values from dataframe 
df = df.dropna()
df.head()
# Out:
#   Unnamed: 0                                              title  \
# 0       8476                       You Can Smell Hillary’s Fear
# 1      10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2       3608        Kerry to go to Paris in gesture of sympathy
# 3      10142  Bernie supporters on Twitter erupt in anger ag...
# 4        875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
x = df.text
y = df.label

# %%
# Split the dataset
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.2, random_state = 7)

# %%
# train the model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(stop_words = 'english',max_df=0.7)
tfidt_train = tfidf.fit_transform(x_train)
tfidt_test = tfidf.transform(x_test)

# let us use the function get_feature_names()
tfidf.get_feature_names()
# Out:
# ['00',
#  '000',
#  '0000',
#  '000000031',
#  '000035',
#  '00006',
#  '0001',
#  '0001pt',
#  '0002',
#  '000billion',
#  '000ft',
#  '000km',
#  '000x',
#  '001',
#  '0011',
#  '003',
#  '004',
#  '004s',
#  '005',
#  '005s',
#  '006',
#  '00684',
#  '006s',
#  '007',
#  '007s',
#  '008',
#  '009',
#  '00am',
#  '00pm',
#  '01',
#  '010',
#  '011',
#  '012',
#  '013',
#  '013c2812c9',
#  '014',
#  '015',
#  '016',
#  '01am',
#  '02',
#  '022',
#  '023',
#  '024',
#  '027',
#  '028',
#  '02welcome',
#  '03',
#  '030',
#  '031',
#  '032',
#  '033',
#  '034',
#  '037',
#  '039',
#  '03eb',
#  '04',
#  '0400',
#  '042',
#  '044',
#  '047',
#  '04pm',
#  '05',
#  '050',
#  '052',
#  '053',
#  '056',
#  '058',
#  '06',
#  '0600',
#  '063',
#  '0640',
#  '066',
#  '068',
#  '06pm',
#  '07',
#  '0700',
#  '071',
#  '075',
#  '0750',
#  '076',
#  '079',
#  '08',
#  '084',
#  '0843',
#  '085',
#  '0851',
#  '089',
#  '09',
#  '091',
#  '098263',
#  '09am',
#  '09pm',
#  '0_65b67362bd',
#  '0_jgdktlmn',
#  '0_kvyhphja',
#  '0b6njlny5j',
#  '0dpbdk6rjd',
#  '0fjjvowyhg8qtskiz',
#  '0h4at2yetra17uxetni02ls2jeg0mty45jrcu7mrzsrpcbq464i',
#  '0hour',
#  '0hq3vb2giv',
#  '0in',
#  '0jsn6pjkan',
#  '0pt',
#  '0t5',
#  '0txrbwvobzz4fi5nksw6k5a6cxzbb3juxthmdiz93cby8gvrqiypzhajvjnt2',
#  '0womdwalmi',
#  '0x',
#  '10',
#  '100',
#  '1000',
#  '10000s',
#  '1000s',
#  '1001',
#  '10021',
#  '10028',
#  '100bn',
#  '100c',
#  '100k',
#  '100percentfedup',
#  '100s',
#  '100th',
#  '101',
#  '1010359',
#  '1019',
#  '101st',
#  '102',
#  '1024026',
#  '1026',
#  '102816',
#  '102m',
#  '103',
#  '1033',
#  '103rd',
#  '104',
#  '1040',
#  '1046870142',
#  '1046870197',
#  '104th',
#  '105',
#  '106',
#  '107',
#  '1070',
#  '107th',
#  '108',
#  '109',
#  '1095',
#  '109th',
#  '10bn',
#  '10ft',
#  '10m',
#  '10m54s',
#  '10mm',
#  '10pm',
#  '10s',
#  '10th',
#  '10ths',
#  '10x',
#  '10yrs',
#  '11',
#  '110',
#  '1100',
#  '1105',
#  '110k',
#  '111',
#  '112',
#  '112145924',
#  '1122930jg',
#  '112th',
#  '113',
#  '1133',
#  '114',
#  '1146',
#  '114th',
#  '115',
#  '11540',
#  '115aug',
#  '115th',
#  '116',
#  '1160',
#  '117',
#  '1176',
#  '118',
#  '1180',
#  '119',
#  '1190',
#  '11am',
#  '11cm',
#  '11e6',
#  '11m',
#  '11mn',
#  '11pm',
#  '11th',
#  '11truther',
#  '12',
#  '120',
#  '1200',
#  '1207',
#  '121',
#  '1219',
#  '122',
#  '1228',
#  '123',
#  '12333',
#  '12345',
#  '124',
#  '1244',
#  '124th',
#  '125',
#  '126',
#  '1261',
#  '1265',
#  '127',
#  '127million',
#  '127th',
#  '128',
#  '1280',
#  '1287',
#  '129',
#  '12am',
#  '12b',
#  '12hdlgeeua87t2ju8m4tbro247yj5u2tvp',
#  '12k',
#  '12m',
#  '12mn',
#  '12news',
#  '12pm',
#  '12sso1zj2bbdguiraddmamlnets7oc1',
#  '12t',
#  '12th',
#  '13',
#  '130',
#  '1300',
#  '1301',
#  '1305',
#  '130500',
#  '130j',
#  '131',
#  '132',
#  '1324',
#  '133',
#  '133rd',
#  '134',
#  '135',
#  '135s',
#  '136',
#  '13603',
#  '137',
#  '138',
#  '139',
#  '1393',
#  '13th',
#  '13½',
#  '14',
#  '140',
#  '1400',
#  '1400s',
#  '1401',
#  '140230',
#  '141',
#  '142',
#  '143',
#  '143m',
#  '144',
#  '14474',
#  '145',
#  '146',
#  '147',
#  '1474',
#  '14774',
#  '148',
#  '149',
#  '1492',
#  '14k',
#  '14kwh',
#  '14m',
#  '14mm',
#  '14th',
#  '15',
#  '150',
#  '1500',
#  '1500s',
#  '150th',
#  '151',
#  '1513',
#  '1517',
#  '152',
#  '1522',
#  '153',
#  '1538',
#  '154',
#  '155',
#  '1555',
#  '156',
#  '157',
#  '158',
#  '1588',
#  '159',
#  '1591',
#  '15am',
#  '15b',
#  '15bn',
#  '15e',
#  '15ft',
#  '15mm',
#  '15pm',
#  '15s',
#  '15th',
#  '15u71',
#  '15yrs',
#  '16',
#  '160',
#  '1600',
#  '1600s',
#  '1603',
#  '1604',
#  '1605',
#  '1606',
#  '161',
#  '1612',
#  '162',
#  '1621',
#  '163',
#  '164',
#  '165',
#  '1650',
#  '1653',
#  '166',
#  '167',
#  '168',
#  '1689',
#  '169',
#  '16k',
#  '16s',
#  '16th',
#  '17',
#  '170',
#  '1700',
#  '17025',
#  '1708',
#  '171',
#  '1711',
#  '172',
#  '173',
#  '1730s',
#  '174',
#  '175',
#  '176',
#  '1766',
#  '177',
#  '1770',
#  '1775',
#  '1776',
#  '1777',
#  '1780',
#  '1784',
#  '1786',
#  '1787',
#  '1788',
#  '1789',
#  '179',
#  '1790',
#  '1791',
#  '1793',
#  '1793qianlong',
#  '1797',
#  '1799',
#  '17k',
#  '17s',
#  '17th',
#  '18',
#  '180',
#  '1800',
#  '1800s',
#  '1801',
#  '1804',
#  '1806',
#  '1808',
#  '181',
#  '1812',
#  '1815',
#  '1816',
#  '1817',
#  '182',
#  '1820',
#  '1820s',
#  '1821',
#  '1822',
#  '1823',
#  '1824',
#  '1825',
#  '1827',
#  '1829',
#  '182nd',
#  '183',
#  '1830',
#  '1830s',
#  '1831',
#  '1834',
#  '1835',
#  '1837',
#  '1839',
#  '184',
#  '1840s',
#  '1841',
#  '1845',
#  '1846',
#  '1847',
#  '1848',
#  '1849',
#  '185',
#  '1850',
#  '1850s',
#  '1851',
#  '1853',
#  '1854',
#  '1855',
#  '1856',
#  '1857',
#  '1858',
#  '1859',
#  '186',
#  '1860',
#  '1860s',
#  '1861',
#  '1862',
#  '1864',
#  '1865',
#  '1868',
#  '1869',
#  '187',
#  '1870s',
#  '1871',
#  '1872',
#  '1873',
#  '1876',
#  '1877',
#  '1878',
#  '188',
#  '1880',
#  '1881',
#  '1882',
#  '1883',
#  '1884',
#  '1885',
#  '1886',
#  '1887',
#  '1888',
#  '189',
#  '1890',
#  '1890s',
#  '1892',
#  '1893',
#  '1895',
#  '1896',
#  '1897',
#  '1898',
#  '1899',
#  '18f',
#  '18th',
#  '19',
#  '190',
#  '1900',
#  '1900s',
#  '1901',
#  '1903',
#  '1904',
#  '1905',
#  '1908',
#  '1909',
#  '191',
#  '1910',
#  '1910s',
#  '1911',
#  '1912',
#  '1913',
#  '1914',
#  '1915',
#  '1916',
#  '1917',
#  '1918',
#  '1919',
#  '192',
#  '1920',
#  '1920s',
#  '1921',
#  '1922',
#  '1923',
#  '1924',
#  '1925',
#  '1926',
#  '1927',
#  '1928',
#  '1929',
#  '193',
#  '1930',
#  '1930s',
#  '1931',
#  '1932',
#  '1933',
#  '1934',
#  '1935',
#  '1936',
#  '1937',
#  '1938',
#  '1939',
#  '194',
#  '1940',
#  '1940s',
#  '1941',
#  '1942',
#  '1943',
#  '1944',
#  '1945',
#  '1946',
#  '1947',
#  '1948',
#  '1949',
#  '195',
#  '1950',
#  '1950s',
#  '1951',
#  '1952',
#  '1953',
#  '1954',
#  '1955',
#  '1956',
#  '1957',
#  '1958',
#  '1959',
#  '195th',
#  '196',
#  '1960',
#  '1960s',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '197',
#  '1970',
#  '1970s',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1980s',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '198974609375',
#  '199',
#  '1990',
#  '1990s',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '19m',
#  '19th',
#  '1_2',
#  '1alvwe4bralkh',
#  '1ao',
#  '1b',
#  '1b1',
#  '1bbswheiehlqifxzus3j35',
#  '1billion',
#  '1bjxt3uhim5fqn93gb0hkxakuarz99d7xcitzftye',
#  '1bn',
#  '1bs',
#  '1hztlj',
#  '1is9krdfnysv0buhf8elizydmsrpwn944flw1tofjw46j4uaxsbrbp284wifmv8n',
#  '1jquvafupk',
#  '1lb',
#  '1lolamarina',
#  '1m',
#  '1m08s',
#  '1mdb',
#  '1mg',
#  '1mgfbvy',
#  '1mm',
#  '1mwvcarc3jsuon8rrxype4espweqzd6zsrbhgh4uqf56pcft2ubnqku4wtgoecsw',
#  '1o6qorkewr',
#  '1oo',
#  '1oth',
#  '1st',
#  '1tr',
#  '1tsp',
#  '1vwbsd9c79',
#  '1wrwsaijjsohk5rzj',
#  '1z',
#  '20',
#  '200',
#  '2000',
#  '20001',
#  '2000mg',
#  '2000s',
#  '2001',
#  '20017',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '200bln',
#  '200k',
#  '200m',
#  '200x',
#  '201',
#  '2010',
#  '2010s',
#  '2011',
#  '2012',
#  '2012campaign',
#  '2012newstart',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '20161026_spain1',
#  '20161026_spain3',
#  '201611061047117877',
#  '2016ers',
#  '2017',
#  '2018',
#  '2019',
#  '202',
#  '2020',
#  '2020s',
#  '2021',
#  '2022',
#  '2023',
#  '2024',
#  '2025',
#  '2026',
#  '2027',
#  '203',
#  '2030',
#  '2030s',
#  '2032',
#  '2033',
#  '2034',
#  '2035',
#  '2040',
#  '2042',
#  '2045',
#  '205',
#  '2050',
#  '20500',
#  '20535',
#  '206',
#  '2060',
#  '2064',
#  '207',
#  '2071',
#  '2074',
#  '208',
#  '209',
#  '2090',
#  '20am',
#  '20book',
#  '20gs',
#  '20k',
#  '20m',
#  '20p',
#  '20power',
#  '20s',
#  '20th',
#  '21',
#  '210',
#  '2100',
#  '2102',
#  '211',
#  '2110',
#  '2117',
#  '212',
#  '213',
#  '214',
#  '2146815',
#  '2149237058061490',
#  '215',
#  '216',
#  '2160',
#  '217',
#  '218',
#  '219',
#  '21mn',
#  '21s',
#  '21st',
#  '21wire',
#  '22',
#  '220',
#  '221',
#  '221day_m25',
#  '222',
#  '223',
#  '2231',
#  '2235360',
#  '224',
#  '225',
#  '226',
#  '226t',
#  '227',
#  '227kg',
#  '228',
#  '229',
#  '22_1171',
#  '22autoupdate',
#  '22basemap',
#  '22default',
#  '22event',
#  '22feed',
#  '22grayscale',
#  '22list',
#  '22listformat',
#  '22lr',
#  '22m3',
#  '22map',
#  '22mapposition',
#  '22nd',
#  '22newest',
#  '22overlays',
#  '22plates',
#  '22pm',
#  '22restrictlisttomap',
#  '22search',
#  '22sort',
#  '22th',
#  '22timezone',
#  '22us1000778i',
#  '22utc',
#  '22viewmodes',
#  '23',
#  '230',
#  '231',
#  '232',
#  '233',
#  '234',
#  '2344',
#  '235',
#  '236',
#  '237',
#  '238',
#  '239',
#  '23a007c77bb4_story',
#  '23rd',
#  '24',
#  '240',
#  '241',
#  '242',
#  '243',
#  '244',
#  '244th',
#  '245',
#  '246',
#  '247',
#  '247th',
#  '248',
#  '24888',
#  '249',
#  '24news',
#  '24th',
#  '25',
#  '250',
#  '2500',
#  '25018606',
#  '251',
#  '2510',
#  '2513',
#  '252',
#  '253',
#  '253207',
#  '254',
#  '25421',
#  '2544',
#  '255',
#  '256',
#  '257',
#  '25751119',
#  '258',
#  '259',
#  '25am',
#  '25m',
#  '25th',
#  '26',
#  '260',
#  '262',
#  '263',
#  '2635',
#  '264',
#  '265',
#  '266',
#  '267',
#  '2670',
#  '268',
#  '269',
#  '26t18',
#  '26th',
#  '27',
#  '270',
#  '2700',
#  '27026',
#  '2703',
#  '271',
#  '2711',
#  '27111',
#  '272',
#  '273',
#  '274',
#  '275',
#  '276',
#  '277',
#  '278',
#  '279',
#  '27th',
#  '28',
#  '280',
#  '281',
#  '282',
#  '283',
#  '284',
#  '28403',
#  '285',
#  '286',
#  '28657',
#  '287',
#  '288',
#  '289',
#  '28th',
#  '29',
#  '290',
#  '2900',
#  '291',
#  '292',
#  '293',
#  '29385',
#  '29385ote',
#  '294',
#  '295',
#  '29549',
#  '296',
#  '297',
#  '298',
#  '29k',
#  '29th',
#  '2a',
#  '2am',
#  '2b',
#  '2bowles',
#  '2c',
#  '2ccrww3wqeay',
#  '2d',
#  '2degrees',
#  '2f',
#  '2f102516_6',
#  '2f16',
#  '2fnews',
#  '2fpreventdisease',
#  '2gary2',
#  '2gkhtimovh',
#  '2hibftjxscml3k8k6mbdi8p9zvcmjsxbppcyrffw9a6t',
#  '2hzuvxyp8k',
#  '2jxewrrk8o',
#  '2kkpwafd9pxaqnwjmpd4amk60l3n',
#  '2l',
#  '2m52s',
#  '2nd',
#  '2o16',
#  '2paragraphs',
#  '2percent',
#  '2plwa3cerym6byp60362co7cpzochyhsvgppzyh0qex',
#  '2yiugiyosv',
#  '2yqga6dd4k',
#  '2yxlvcf03qflflgzzfn7fcv5jw',
#  '2zksz3xesc7mmpgrzanh4pk1dlr',
#  '2½',
#  '30',
#  '300',
#  '3000',
#  '3001',
#  '301',
#  '302',
#  '3037',
#  '304',
#  '305',
#  '306',
#  '307',
#  '307th',
#  '308',
#  '309',
#  '30am',
#  '30b',
#  '30k',
#  '30mki',
#  '30pm',
#  '30s',
#  '30th',
#  '30th_in',
#  '31',
#  '310',
#  '313',
#  '315',
#  '316',
#  '317',
#  '31715',
#  '31721',
#  '318',
#  '319',
#  '31909',
#  '31am',
#  '31s',
#  '31st',
#  '32',
#  '320',
#  '3200',
#  '321',
#  '3222705',
#  '3225440',
#  '323',
#  '324',
#  '325',
#  '326',
#  '328',
#  '32833',
#  '329',
#  '32937',
#  '33',
#  '330',
#  '33010',
#  '331',
#  '332',
#  '333',
#  '334',
#  '33552',
#  '336',
#  '337',
#  '3370',
#  '33713',
#  '33722',
#  '33739',
#  '338',
#  '339',
#  '33a',
#  '33k',
#  '33rd',
#  '33s',
#  '34',
#  '340',
#  '34000',
#  '342',
#  '343',
#  '345',
#  '3454',
#  '346',
#  '347',
#  '348',
#  '349',
#  '34th',
#  '35',
#  '350',
#  '3500',
#  '351',
#  '3515',
#  '352',
#  '353',
#  '354',
#  '3540',
#  '355',
#  '355th',
#  '356',
#  '357',
#  '3570',
#  '359',
#  '35am',
#  '35k',
#  '36',
#  ...]

# %%
# Let us use the function get_stop_words()
tfidf.get_stop_words()
# Out:
# frozenset({'a',
#            'about',
#            'above',
#            'across',
#            'after',
#            'afterwards',
#            'again',
#            'against',
#            'all',
#            'almost',
#            'alone',
#            'along',
#            'already',
#            'also',
#            'although',
#            'always',
#            'am',
#            'among',
#            'amongst',
#            'amoungst',
#            'amount',
#            'an',
#            'and',
#            'another',
#            'any',
#            'anyhow',
#            'anyone',
#            'anything',
#            'anyway',
#            'anywhere',
#            'are',
#            'around',
#            'as',
#            'at',
#            'back',
#            'be',
#            'became',
#            'because',
#            'become',
#            'becomes',
#            'becoming',
#            'been',
#            'before',
#            'beforehand',
#            'behind',
#            'being',
#            'below',
#            'beside',
#            'besides',
#            'between',
#            'beyond',
#            'bill',
#            'both',
#            'bottom',
#            'but',
#            'by',
#            'call',
#            'can',
#            'cannot',
#            'cant',
#            'co',
#            'con',
#            'could',
#            'couldnt',
#            'cry',
#            'de',
#            'describe',
#            'detail',
#            'do',
#            'done',
#            'down',
#            'due',
#            'during',
#            'each',
#            'eg',
#            'eight',
#            'either',
#            'eleven',
#            'else',
#            'elsewhere',
#            'empty',
#            'enough',
#            'etc',
#            'even',
#            'ever',
#            'every',
#            'everyone',
#            'everything',
#            'everywhere',
#            'except',
#            'few',
#            'fifteen',
#            'fifty',
#            'fill',
#            'find',
#            'fire',
#            'first',
#            'five',
#            'for',
#            'former',
#            'formerly',
#            'forty',
#            'found',
#            'four',
#            'from',
#            'front',
#            'full',
#            'further',
#            'get',
#            'give',
#            'go',
#            'had',
#            'has',
#            'hasnt',
#            'have',
#            'he',
#            'hence',
#            'her',
#            'here',
#            'hereafter',
#            'hereby',
#            'herein',
#            'hereupon',
#            'hers',
#            'herself',
#            'him',
#            'himself',
#            'his',
#            'how',
#            'however',
#            'hundred',
#            'i',
#            'ie',
#            'if',
#            'in',
#            'inc',
#            'indeed',
#            'interest',
#            'into',
#            'is',
#            'it',
#            'its',
#            'itself',
#            'keep',
#            'last',
#            'latter',
#            'latterly',
#            'least',
#            'less',
#            'ltd',
#            'made',
#            'many',
#            'may',
#            'me',
#            'meanwhile',
#            'might',
#            'mill',
#            'mine',
#            'more',
#            'moreover',
#            'most',
#            'mostly',
#            'move',
#            'much',
#            'must',
#            'my',
#            'myself',
#            'name',
#            'namely',
#            'neither',
#            'never',
#            'nevertheless',
#            'next',
#            'nine',
#            'no',
#            'nobody',
#            'none',
#            'noone',
#            'nor',
#            'not',
#            'nothing',
#            'now',
#            'nowhere',
#            'of',
#            'off',
#            'often',
#            'on',
#            'once',
#            'one',
#            'only',
#            'onto',
#            'or',
#            'other',
#            'others',
#            'otherwise',
#            'our',
#            'ours',
#            'ourselves',
#            'out',
#            'over',
#            'own',
#            'part',
#            'per',
#            'perhaps',
#            'please',
#            'put',
#            'rather',
#            're',
#            'same',
#            'see',
#            'seem',
#            'seemed',
#            'seeming',
#            'seems',
#            'serious',
#            'several',
#            'she',
#            'should',
#            'show',
#            'side',
#            'since',
#            'sincere',
#            'six',
#            'sixty',
#            'so',
#            'some',
#            'somehow',
#            'someone',
#            'something',
#            'sometime',
#            'sometimes',
#            'somewhere',
#            'still',
#            'such',
#            'system',
#            'take',
#            'ten',
#            'than',
#            'that',
#            'the',
#            'their',
#            'them',
#            'themselves',
#            'then',
#            'thence',
#            'there',
#            'thereafter',
#            'thereby',
#            'therefore',
#            'therein',
#            'thereupon',
#            'these',
#            'they',
#            'thick',
#            'thin',
#            'third',
#            'this',
#            'those',
#            'though',
#            'three',
#            'through',
#            'throughout',
#            'thru',
#            'thus',
#            'to',
#            'together',
#            'too',
#            'top',
#            'toward',
#            'towards',
#            'twelve',
#            'twenty',
#            'two',
#            'un',
#            'under',
#            'until',
#            'up',
#            'upon',
#            'us',
#            'very',
#            'via',
#            'was',
#            'we',
#            'well',
#            'were',
#            'what',
#            'whatever',
#            'when',
#            'whence',
#            'whenever',
#            'where',
#            'whereafter',
#            'whereas',
#            'whereby',
#            'wherein',
#            'whereupon',
#            'wherever',
#            'whether',
#            'which',
#            'while',
#            'whither',
#            'who',
#            'whoever',
#            'whole',
#            'whom',
#            'whose',
#            'why',
#            'will',
#            'with',
#            'within',
#            'without',
#            'would',
#            'yet',
#            'you',
#            'your',
#            'yours',
#            'yourself',
#            'yourselves'})

# %%
# Let us use the build_analyzer() function
tfidf.build_analyzer()
# Out:
# functools.partial(<function _analyze at 0x00000196EA729820>, ngrams=<bound method _VectorizerMixin._word_ngrams of TfidfVectorizer(max_df=0.7, stop_words='english')>, tokenizer=<built-in method findall of re.Pattern object at 0x00000196EA835AC0>, preprocessor=functools.partial(<function _preprocess at 0x00000196EA729790>, accent_function=None, lower=True), decoder=<bound method _VectorizerMixin.decode of TfidfVectorizer(max_df=0.7, stop_words='english')>, stop_words=frozenset({'again', 'few', 'i', 'and', 'sometime', 'mill', 'but', 'many', 'which', 'not', 'everything', 'our', 'more', 'nothing', 'found', 'afterwards', 'sincere', 'some', 'amoungst', 'anywhere', 'yet', 'whenever', 'or', 'seems', 'sometimes', 'latterly', 'per', 'anyhow', 'hereupon', 'fill', 'out', 'wherein', 'nine', 'ourselves', 'whose', 'own', 'last', 'under', 'where', 'five', 'herein', 'became', 'whence', 'elsewhere', 'him', 'now', 'someone', 'herself', 'how', 'in', 'becomes', 'this', 'we', 'see', 'yourselves', 'whoever', 'below', 'such', 'fire', 'you', 'was', 'hence', 'throughout', 'hers', 'she', 'latter', 'whereby', 'beyond', 'amount', 'etc', 'until', 'interest', 'thus', 'twenty', 'done', 'cry', 'whither', 'may', 'being', 'will', 'indeed', 'their', 'almost', 'has', 'enough', 'it', 'against', 'hereby', 'upon', 'another', 'before', 'first', 'take', 'without', 'should', 'any', 'because', 'go', 'those', 'am', 'twelve', 'very', 'co', 'inc', 'whole', 'had', 'behind', 'onto', 'themselves', 'thereafter', 'cant', 'other', 'often', 'along', 'itself', 'namely', 'please', 'everyone', 'himself', 'so', 'whereas', 'to', 'down', 'an', 'third', 'within', 'bottom', 'cannot', 'top', 'from', 'us', 'both', 'neither', 'give', 'there', 'when', 'others', 'eight', 'her', 'back', 'be', 'describe', 'serious', 'never', 'though', 'two', 'become', 'less', 'rather', 'however', 'find', 'except', 'although', 'been', 'a', 'can', 'wherever', 'thereupon', 'thin', 'thereby', 'since', 'them', 'same', 'together', 'de', 'beforehand', 'seemed', 'would', 'ours', 'even', 'if', 'next', 'nowhere', 'anyone', 'nevertheless', 'while', 'side', 'eg', 'fifty', 'ten', 'its', 'towards', 'well', 'move', 'couldnt', 'must', 'might', 'each', 'all', 'of', 'due', 'are', 'further', 'seem', 'ie', 'beside', 'somehow', 'why', 'thence', 'about', 'thru', 'otherwise', 'still', 'hasnt', 'these', 'that', 'into', 'anyway', 'whereafter', 'whatever', 'off', 'is', 'here', 'whether', 'his', 'what', 'during', 'whereupon', 'hundred', 'un', 'perhaps', 'formerly', 'keep', 'alone', 'toward', 'eleven', 'nobody', 'most', 're', 'besides', 'over', 'at', 'sixty', 'around', 'across', 'much', 'through', 'who', 'no', 'everywhere', 'once', 'by', 'were', 'up', 'three', 'yours', 'mine', 'thick', 'already', 'then', 'becoming', 'between', 'none', 'whom', 'hereafter', 'something', 'con', 'four', 'front', 'former', 'every', 'via', 'your', 'fifteen', 'the', 'amongst', 'either', 'forty', 'moreover', 'my', 'bill', 'full', 'show', 'on', 'detail', 'system', 'several', 'do', 'he', 'for', 'part', 'with', 'also', 'always', 'nor', 'name', 'made', 'ltd', 'above', 'call', 'ever', 'too', 'empty', 'after', 'anything', 'get', 'therefore', 'among', 'meanwhile', 'one', 'noone', 'somewhere', 'six', 'me', 'else', 'mostly', 'myself', 'could', 'put', 'they', 'have', 'yourself', 'than', 'therein', 'least', 'as', 'only', 'seeming'}))

# %%
# Let us use the function build_preprocessor()
tfidf.build_preprocessor()
# Out:
# functools.partial(<function _preprocess at 0x00000196EA729790>, accent_function=None, lower=True)

# %%
# use the class PassiveAggressiveClassifier and predict the model
pac = PassiveAggressiveClassifier()
pac.fit(tfidt_train,y_train)
y_pred = pac.predict(tfidt_test)

# %%
# calculate the accuracy
round(accuracy_score(y_test,y_pred),2)*100
# Out:
# 87.0

# %%
print(type(x_train))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(x_test))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print(type(y_train))
# Out:
# <class 'pandas.core.series.Series'>
